# %%
# !git clone https://github.com/reachsumit/deep-unet-for-satellite-image-segmentation.git
# Out:
# Cloning into 'deep-unet-for-satellite-image-segmentation'...
# remote: Enumerating objects: 92, done.
# remote: Total 92 (delta 0), reused 0 (delta 0), pack-reused 92
# Unpacking objects: 100% (92/92), done.
# Checking out files: 100% (61/61), done.

# %%
cd deep-unet-for-satellite-image-segmentation/
# Out:
# /content/deep-unet-for-satellite-image-segmentation

# %%
pwd
# Out:
# '/content/deep-unet-for-satellite-image-segmentation'

# %%
ls
# Out:
# data/            map.tif      run.sbatch*        unet_model_deeper.py*
# gen_patches.py*  predict.py*  tensorboard_unet/  unet_model.py*
# log_unet.csv     README.md    train_unet.py*

# %%
# !pip install tifffile
# !python train_unet.py
# Out:
# Collecting tifffile
#   Downloading https://files.pythonhosted.org/packages/2f/00/e04382fa315a024daad9aa57f93f2321152cd31ba33b73a77a691716ced2/tifffile-2018.11.6-py2.py3-none-any.whl (120kB)
#     100% |████████████████████████████████| 122kB 3.9MB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from tifffile) (1.14.6)
# Installing collected packages: tifffile
# Successfully installed tifffile-2018.11.6
# Using TensorFlow backend.
# Reading images
# 01 read
# 02 read
# 03 read
# 04 read
# 05 read
# 06 read
# 07 read
# 08 read
# 09 read
# 10 read
# 11 read
# 12 read
# 13 read
# 14 read
# 15 read
# 16 read
# 17 read
# 18 read
# 19 read
# 20 read
# 21 read
# 22 read
# 23 read
# 24 read
# Images were read
# start train net
# Generated 4000 patches
# tcmalloc: large alloc 6553600000 bytes == 0x6e9f4000 @  0x7f671f7e81e7 0x7f671d59ea41 0x7f671d601c13 0x7f671d6050c4 0x7f671d605605 0x7f671d69c201 0x511b75 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f6070 0x510c78 0x5119bd 0x4f5277 0x4f3338 0x4f4ab3 0x640862 0x64091a 0x6429e0 0x634117 0x4b6e80 0x7f671f3e5b97 0x5bf75a
# tcmalloc: large alloc 4096000000 bytes == 0x1f5cd8000 @  0x7f671f7e81e7 0x7f671d59ea41 0x7f671d601c13 0x7f671d6050c4 0x7f671d605605 0x7f671d69c201 0x511b75 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f6070 0x510c78 0x5119bd 0x4f5277 0x4f3338 0x4f4ab3 0x640862 0x64091a 0x6429e0 0x634117 0x4b6e80 0x7f671f3e5b97 0x5bf75a
# Generated 1000 patches
# tcmalloc: large alloc 1638400000 bytes == 0x2e9f18000 @  0x7f671f7e81e7 0x7f671d59ea41 0x7f671d601c13 0x7f671d6050c4 0x7f671d605605 0x7f671d69c201 0x511b75 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f6070 0x510c78 0x5119bd 0x4f5277 0x4f3338 0x4f4ab3 0x640862 0x64091a 0x6429e0 0x634117 0x4b6e80 0x7f671f3e5b97 0x5bf75a
# ^C
